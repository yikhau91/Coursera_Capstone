# %% [markdown]
# # SEATTLE ACCIDENT DATA

# %% [markdown]
# ## 1.0 PROBLEM STATEMENT

# %%
Impact of traffic?

# %% [markdown]
# ## 2.0 EXPLORATORY ANALYSIS

# %%
#Option
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# Import library
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load datasets
acd = pd.read_csv(r'C:\Users\yikha\Documents\GitHub\Coursera_Capstone\Data\Data-Collisions.csv',index_col = 'OBJECTID',
                 dtype = {"SDOTCOLNUM" : "object", "SDOT_COLCODE" : "object"})
acd
# Out:
# C:\Users\yikha\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (33) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Check whether there are duplicate records
chkuniqueid = acd.index.duplicated(keep=False)
np.unique(chkuniqueid, return_counts=True)
# Out:
# (array([False]), array([194673], dtype=int64))

# %%
acd.iloc[:,33]
# Out:
# OBJECTID
# 1                                         Entering at angle
# 2         From same direction - both going straight - bo...
# 3                                    One parked--one moving
# 4                          From same direction - all others
# 5                                         Entering at angle
#                                 ...
# 219543      From opposite direction - both moving - head-on
# 219544    From same direction - both going straight - bo...
# 219545    From opposite direction - one left turn - one ...
# 219546                         Vehicle Strikes Pedalcyclist
# 219547    From same direction - both going straight - on...
# Name: ST_COLDESC, Length: 194673, dtype: object

# %%
acd['SDOTCOLNUM'].dtype
# Out:
# dtype('O')

# %%
# Check the data type of all column
acd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 194673 entries, 1 to 219547
# Data columns (total 37 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   SEVERITYCODE    194673 non-null  int64
#  1   X               189339 non-null  float64
#  2   Y               189339 non-null  float64
#  3   INCKEY          194673 non-null  int64
#  4   COLDETKEY       194673 non-null  int64
#  5   REPORTNO        194673 non-null  object
#  6   STATUS          194673 non-null  object
#  7   ADDRTYPE        192747 non-null  object
#  8   INTKEY          65070 non-null   float64
#  9   LOCATION        191996 non-null  object
#  10  EXCEPTRSNCODE   84811 non-null   object
#  11  EXCEPTRSNDESC   5638 non-null    object
#  12  SEVERITYCODE.1  194673 non-null  int64
#  13  SEVERITYDESC    194673 non-null  object
#  14  COLLISIONTYPE   189769 non-null  object
#  15  PERSONCOUNT     194673 non-null  int64
# ...

# %%
# Drop redundant columns
acd['SEVERITYCODE'].equals(acd['SEVERITYCODE.1'])
acd.drop(columns=['SEVERITYCODE.1'])

#Treat datatype
acd['SDOTCOLNUM'].astype('object')
acd['SDOT_COLCODE'].astype('object')
acd.todatetime(acd[[]])
# Out:
#           SEVERITYCODE           X          Y  INCKEY  COLDETKEY REPORTNO  \
# OBJECTID
# 1                    2 -122.323148  47.703140    1307       1307  3502005
# 2                    1 -122.347294  47.647172   52200      52200  2607959
# 3                    1 -122.334540  47.607871   26700      26700  1482393
# 4                    1 -122.334803  47.604803    1144       1144  3503937
# 5                    2 -122.306426  47.545739   17700      17700  1807429
# ...                ...         ...        ...     ...        ...      ...
# 219543               2 -122.290826  47.565408  309534     310814  E871089
# 219544               1 -122.344526  47.690924  309085     310365  E876731
# 219545               2 -122.306689  47.683047  311280     312640  3809984
# 219546               2 -122.355317  47.678734  309514     310794  3810083
# 219547               1 -122.289360  47.611017  308220     309500  E868008
#
#            STATUS      ADDRTYPE   INTKEY  \
# OBJECTID
# ...

# %% [markdown]
# ## 3.0 DATA PREPARATION

# %% [markdown]
# ## 4.0 MODELLING

# %% [markdown]
# ## 5.0 DISCUSSION
